# %%
# Essentials
import numpy as np
import xarray as xr
import pandas as pd
from datetime import datetime, timedelta

# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors
from matplotlib.colors import ListedColormap, BoundaryNorm, TwoSlopeNorm
import matplotlib.ticker as ticker
from matplotlib import patches
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
from scipy.interpolate import RegularGridInterpolator
from scipy.stats import gaussian_kde
import physoce
from physoce import oceans as oc

# %% [markdown]
# #### Downloading the xml metadata file

# %%
import requests

url = 'https://data.piscoweb.org/metacat/d1/mn/v2/object/urn:uuid:f22f1cb1-0aae-4506-890a-3d9125d9b3e2'
response = requests.get(url)
with open('stillwater-PISCO-ADCP.xml', 'wb') as f:
    f.write(response.content)

# %% [markdown]
# ### Load data from txt file

# %% [markdown]
# [Here is the link to the data] (https://search.dataone.org/view/doi%3A10.6085%2FC3H597#urn%3Auuid%3Af22f1cb1-0aae-4506-890a-3d9125d9b3e2)

# %%
# Load ADCP dataset
adcp1 = pd.read_csv("/Users/jessicafranks/grad_school/grad_thesis/thesis-python/dispersal-model/ADCP-data/PISCO-adcp/PISCO-SWC-ADCP.txt", sep=r'\s+', header = 0)
#what does the time variable look like?
adcp1.time
# Out:
# 0         20:39:33.00Z
# 1         20:39:33.00Z
# 2         20:39:33.00Z
# 3         20:39:33.00Z
# 4         20:39:33.00Z
#               ...
# 574933    22:04:33.00Z
# 574934    22:04:33.00Z
# 574935    22:04:33.00Z
# 574936    22:04:33.00Z
# 574937    22:04:33.00Z
# Name: time, Length: 574938, dtype: object

# %%
# Convert 'time' column to datetime with UTC timezone handling
adcp1['time'] = pd.to_datetime(adcp1['time'], utc=True)

# Apply quality control filter
qc_mask = (adcp1.flag == 0) & (adcp1.eatward != 9999) & (adcp1.northward != 9999)
adcp1_qc = adcp1[qc_mask]

# Select numeric columns to average
numeric_cols = ['eatward', 'northward']

# Group and average over time and depth
adcp1_qc_agg = adcp1_qc.groupby(['time', 'depth'])[numeric_cols].mean().reset_index()

# Sort and prepare for interpolation
time_values = pd.DatetimeIndex(adcp1_qc_agg['time'].unique())
time_values = time_values.sort_values()
bindist = np.sort(adcp1_qc_agg['depth'].unique())

time_sec = (time_values - time_values[0]) / np.timedelta64(1, 's')
adcp_duration_sec = time_sec[-1] # total duration of ADCP data in seconds

# Pivot to 2D arrays for interpolation
u_data = adcp1_qc_agg.pivot(index='time', columns='depth', values='eatward').loc[time_values, bindist].values
v_data = adcp1_qc_agg.pivot(index='time', columns='depth', values='northward').loc[time_values, bindist].values

# Create interpolators
u_interp = RegularGridInterpolator((time_sec, bindist), u_data, bounds_error=False, fill_value=0)
v_interp = RegularGridInterpolator((time_sec, bindist), v_data, bounds_error=False, fill_value=0)
# Out:
# /var/folders/t6/9mj5h_qd17d697_8bs8tsr2c0000gn/T/ipykernel_29762/54111634.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   adcp1['time'] = pd.to_datetime(adcp1['time'], utc=True)

# %% [markdown]
# ### ADV Data to get wave height and period

# %%
# ADV spectra
eps1 = xr.open_dataset("/Users/jessicafranks/grad_school/grad_thesis/thesis-python/dispersal-model/ADV-data/eps1_final.nc")

# %% [markdown]
# Below calcualtions are from Logan's Kelp-Forest-Hydrodynamics github repository
# Data_overview.ipynb

# %%
#Calculate wave height and period using moment integrals from Jones and Monosmith (2007)
epsDS1 = eps1.copy(deep=True)
wavetailCutoff = epsDS1.WavetailEnd.values
H = -epsDS1.Z.values
Hrms_arr = np.zeros(len(epsDS1.BurstCounter))
Hs_arr = np.zeros(len(epsDS1.BurstCounter))
Tavg_arr = np.zeros(len(epsDS1.BurstCounter))
waveOrbital_arr = np.zeros(len(epsDS1.BurstCounter))
waveAdvect_arr = np.zeros(len(epsDS1.BurstCounter))

for i in enumerate(epsDS1.BurstCounter.values):
    Snn = epsDS1.Snn[i[0]][1:wavetailCutoff[i[0]]+1].values
    omega = epsDS1.omega[1:wavetailCutoff[i[0]]+1].values
    if wavetailCutoff[i[0]] >= 25:
        Snn = epsDS1.Snn[i[0]][1:23].values
        omega = epsDS1.omega[1:23].values
    m0 = np.trapz((omega**0)*Snn, omega)
    m2 = np.trapz((omega**2)*Snn, omega)

    Hrms_arr[i[0]] = 2*np.sqrt(2*m0) #Root mean square wave height
    Hs_arr[i[0]] = 4 * np.sqrt(m0)   #Significant wave height
    Tavg_arr[i[0]] = (2*np.pi) * np.sqrt(m0/m2) #Average wave period
    waveOrbital_arr[i[0]] = oc.ubwave(Hs_arr[i[0]], Tavg_arr[i[0]], H[i[0]]) #Estimate wave orbital velocity at depth "H"
    
    #U = epsDS.WaveOrbitalVel.values[i[0]]
    omega_t = (2*np.pi)/Tavg_arr[i[0]]
    t = np.linspace(0,Tavg_arr[i[0]],100)
    d = -(waveOrbital_arr[i[0]])*np.cos(omega_t*t)+waveOrbital_arr[i[0]]
    waveAdvect_arr[i[0]] = np.trapz(d,t)/2
    
epsDS1["Hrms"] = (["time_start"], Hrms_arr,{'Description':'Root mean square wave height','Units':'m'})
epsDS1["Hs"] = (["time_start"], Hs_arr,{'Description':'Significant wave height','Units':'m'})
epsDS1["Tavg"] = (["time_start"], Tavg_arr,{'Description':'Average wave period','Units':'s'})
epsDS1["WaveOrbitalVel"] = (["time_start"], waveOrbital_arr,{'Description':'Wave orbital velocity estimate','Units':'[m/s]'})
epsDS1["WaveOrbitalAdvec"] = (["time_start"], waveAdvect_arr,{'Description':'Estimate advection distance of wave orbital','Units':'m'})

# %%
#guide for what happens if particles hit the surface
def u_interp_extended(t, z):
    z_max = bindist.max()
    if z > z_max:
        return u_interp((t, z_max))
    else:
        return u_interp((t, z))

def v_interp_extended(t, z):
    z_max = bindist.max()
    if z > z_max:
        return v_interp((t, z_max))
    else:
        return v_interp((t, z))

# %% [markdown]
# **Setting up some parameters**

# %%
kv = 1.22e-6 # m^2/s^-1 this is the kinematic velocity of seawater (Grady 2024)
diameter = 0.3 #meters
# Grady 2024
max_current = 0.025 # m/s
min_current = 0.007 # m/s
re = (max_current * diameter) / kv # to be calculated later once I get diameter values for stephy in the field

# %%
n_particles = 300
release_height = 0.3 #meters
plant_depth = 21 #meters
sinking_speeds = [0.0009020192] # m/s
bottom_roughness = 0.08 # meters
Kz = 1e-4
dt = 60
settle_fraction = 0.9
kappa = 0.41

#wave_height = 0.23 # meters (grady 2024)
#wave_period = 7.4 #second (grady 2024)
g = 9.81

#L = (g * wave_period**2) / (2 * np.pi) * np.tanh((2 * np.pi * plant_depth) / (wave_period**2 * g))
#k = 2 * np.pi / L
#U_s = (np.pi * wave_height**2) / (2 * wave_period * np.sinh(k * plant_depth)**2)

def stokes_drift(z, H, T):
    """Calculate Stokes drift at depth z given wave height H and wave period T."""
    def dispersion_relation(k):
        return g * k * np.tanh(k * plant_depth) - (2 * np.pi / T)**2
    from scipy.optimize import fsolve
    k_initial = 2 * np.pi / (g * T**2 / (2 * np.pi))  # initial guess
    k = fsolve(dispersion_relation, k_initial)[0]
    
    numerator = k * np.cosh(2 * k * (z + plant_depth))
    denominator = np.sinh(k * plant_depth)**2
    return (np.pi * H**2) / (2 * T) * numerator / denominator

# %%
def drag_coefficient(z, z0=0.08):
    """Compute drag coefficient CD using log-layer formulation."""
    kappa = 0.41
    return (kappa / np.log(z/z0))**2 if z > z0 else 0

def calculate_length_scales(H, T, u_star_c, u_star_w):
    """
    Calculate mixing length scales l_c and l_w.
    
    Parameters:
    - H: total water depth (m)
    - T: wave period (s)
    - u_star_c: friction velocity from currents (m/s)
    - u_star_w: friction velocity from waves (m/s)
    
    Returns:
    - l_c: mixing length scale from current (m)
    - l_w: mixing length scale from waves (m)
    """
    g = 9.81
    # Calculate wavelength L (using linear wave theory)
    # deep water wavelength approximation
    L0 = g * T**2 / (2 * np.pi)

    # If depth is shallow, use wave dispersion relation with tanh(kH)
    # Iteratively solve for k (wavenumber)
    def dispersion_relation(k):
        return g * k * np.tanh(k * H) - (2 * np.pi / T)**2

    from scipy.optimize import fsolve
    k_initial_guess = 2 * np.pi / L0
    k_solution = fsolve(dispersion_relation, k_initial_guess)[0]

    # wavelength
    L = 2 * np.pi / k_solution

    # Combined friction velocity from current and wave
    u_star_cw = np.sqrt(u_star_c**2 + u_star_w**2)

    omega = 2 * np.pi / T
    if omega == 0 or u_star_cw == 0:
        lw = 1e-6 # just a small positive default to avoid dividing by 0
    else:
        # Wave mixing length scale
        lw = 2 * k_solution * u_star_cw / omega

    # Current mixing length scale (shallow water assumption)
    lc = H / 2

    return lc, lw

# %%
def friction_factor(u_b, rho=1025, z=1.0, z0=0.08):
    """Estimate bottom shear stress and shear velocity."""
    CD = drag_coefficient(z, z0)
    tau_b = rho * CD * u_b**2 #bottom shear stress from currents
    u_star_c = np.sqrt(tau_b / rho)
    return tau_b, u_star_c
    
def diffusivity_Kz(z, u_b, u_wave, lc, lw, rho=1025, kappa=0.41, z0=0.08):
    """
    Calculate depth-dependent vertical turbulent diffusivity Kz at depth z.
    
    Parameters:
    - z: particle depth
    - u_b: near-bottom current velocity
    - u_wave: wave orbital velocity
    - rho: water density
    - lc: mixing length scale from currents
    - lw: mixing length scale from waves
    - kappa: turbulent mixing coefficient
    - z0: bottom roughness length
    """
    # Current shear stress and velocity
    tau_b, u_star_c = friction_factor(u_b, rho=rho, z=z, z0=z0)

    # Wave shear stress and velocity
    f_w = 2 * (u_wave / u_b)**2 if u_b > 0 else 0
    tau_w = 0.5 * rho * f_w * u_wave**2
    u_star_w = np.sqrt(tau_w / rho)

    # Turbulent kinetic energy terms (depth-dependent)
    term_current = u_star_c**2 * np.exp(-2 * z / lc)
    term_wave = u_star_w**2 * np.exp(-2 * z / lw)

    return kappa * np.sqrt(term_current + term_wave)

# %% [markdown]
# **Defining the particle class**

# %%
# Propagule definitions
class Particle:
    def __init__(self, z=release_height):
        self.x = 0.0
        self.y = 0.0
        self.z = z
        self.settled = False
        self.settle_time = None

# %% [markdown]
# #### Creating the simulation function

# %%
# Run simulation Function
def run_simulation(release_height, plant_depth, sinking_speeds,
                  Kz_mode='depth-dependent', Kz_constant=1e-4):
    particles = [Particle(z=release_height) for _ in range(n_particles)]
    positions = []
    t = 0
    settled_count = 0

    #run for 50 days instead of full ADCP time (based on zygote viability)
    max_simulation_time_sec = 50 * 24 * 60 * 60 # 50 days in seconds
    max_time_steps = int(max_simulation_time_sec / dt)
    
    while settled_count < settle_fraction * n_particles and t < max_time_steps:
        t_sec = (t * dt) % adcp_duration_sec  # loop the ADCP data
        settled_count = 0
        current_positions = []

        # === Precompute wave + shear values at current time step === #
        t_index = int((t_sec / adcp_duration_sec) * len(epsDS1.time_start))
        H_now = epsDS1.Hs.values[t_index]
        T_now = epsDS1.Tavg.values[t_index]
        u_wave_orbital = waveOrbital_arr[t_index]

        # Near-bottom current velocity (bindist.min() is lowest ADCP bin)
        u_b = u_interp((t_sec, bindist.min()))

        # Avoid divide-by-zero
        if u_b > 0:
            f_w = 2 * (u_wave_orbital / u_b)**2
        else:
            f_w = 0

        rho = 1025
        tau_w = 0.5 * rho * f_w * u_wave_orbital**2
        u_star_w = np.sqrt(tau_w / rho)

        # Bottom shear stress from current
        tau_b, u_star_c = friction_factor(u_b, rho=rho, z=1.0, z0=bottom_roughness)

        # Length scales from both wave and current
        lc, lw = calculate_length_scales(plant_depth, T_now, u_star_c, u_star_w)

        # === Now loop over particles === #
        for p in particles:
            if not p.settled:
                u = u_interp_extended(t_sec, p.z)
                v = v_interp_extended(t_sec, p.z)

                # Add stokes drift
                stokes_u = stokes_drift(p.z, H_now, T_now)
                u += stokes_u
                # Update horizontal position
                p.x += u * dt
                p.y += v * dt

                # Vertical update
                dz_sink = sinking_speeds * dt
                Kz_local = diffusivity_Kz(
                    p.z,
                    u_b=u_b,
                    u_wave=u_wave_orbital,
                    rho=rho,
                    lc=lc,
                    lw=lw,
                    kappa=kappa,
                    z0=bottom_roughness
                )
                dz_diff = np.random.normal(0, np.sqrt(2 * Kz_local * dt))

                #apply vertical changes
                p.z -= dz_sink
                p.z += dz_diff

                #== surface conditions===
                # Clamp particle depth at bottom but don't settle at the surface
                if p.z >= plant_depth:
                    p.z = plant_depth - 0.01 #just under the surface

                #== bottom conditions==
                # settle if at bobottom
                elif p.z <= bottom_roughness:
                    p.z = 0
                    p.settled = True
                    p.settle_time = t * dt
                    settled_count += 1

               # if t % 100 == 0 and p == particles[0]:  # sample one particle every 100 timesteps
                 #   print(f"t: {t*dt:.0f}s | u: {u:.3f} m/s | v: {v:.3f} m/s | Stokes: {stokes_u:.3f}")

               # if t % 100 == 0 and p == particles[0]: #track one particle's drift
                   # print(f"t={t*dt}s | x={p.x:.1f} m | y={p.y:.1f} m | z={p.z:.1f} m")

            current_positions.append((p.x, p.y, p.z))

        positions.append(current_positions)
        t += 1

    #settling times and final positions
    settling_times = []
    final_positions = []
    settled_flags = []

    for p in particles:
        final_positions.append((p.x, p.y, p.z))
        if p.settled:
            settling_times.append(p.settle_time / 3600 ) #convert to hours
            settled_flags.append(True)
        else:
            settling_times.append(None)
            settled_flags.append(False)

    return (
        np.array(final_positions), 
        np.array(settling_times), # in hours
        np.array(settled_flags)
    )
    #return np.array(positions[-1]) if positions else np.array([])

# %% [markdown]
# #### Running it

# %%
# Run simulations
release_heights = np.arange(0.5, 12.0, 0.05) #from 30 cm to just below 12m, every 5 cm
plant_depths = [21.0]
sinking_speeds = [0.0009020192] # m/s

settling_records = [] #stores release_height, settling_time
all_final_positions = []
results = {} #use dictionary here, not list

#to run with a constant diffusivity 
# run_simulation(r, plant_depth, sinking_speeds, Kz_mode='constant', Kz_constant=1e-3)

for r in release_heights:
    for pd_val in plant_depths:
        for ss in sinking_speeds:
            label = f"r{r}_pd{pd_val}"
           
            final_positions, settling_times, settled_flags = run_simulation(
                release_height=r,
                plant_depth=pd_val,
                sinking_speeds=ss
            )

            results[label] = (final_positions, settling_times, settled_flags)


            if len(final_positions) > 0:
                release_column = np.full((final_positions.shape[0], 1), r)
                final_with_release = np.hstack((final_positions, release_column))
                all_final_positions.append(final_with_release)

                # Add settling records
                for i, pos in enumerate(final_positions):
                    if not np.any(np.isnan(pos)):
                        release_column = np.array([[r]])
                        final_with_release = np.hstack((pos.reshape(1, -1), release_column))
                        all_final_positions.append(final_with_release)

                        if settled_flags[i]:
                            settling_records.append((r, settling_times[i]))

# %%
all_final_positions = np.vstack(all_final_positions)
x, y, z, release_h = all_final_positions[:, 0], all_final_positions[:, 1], all_final_positions[:, 2], all_final_positions[:, 3]

# %% [markdown]
# ### Plotting

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(x, y, c=release_h, cmap='turbo', s=10)  # 'turbo' or 'viridis' are good for heatmaps
cbar = plt.colorbar(scatter)
cbar.set_label("Release Height (m)", fontsize=12)

plt.xlabel("Eastward Displacement (m)")
plt.ylabel("Northward Displacement (m)")
plt.title("Final Particle Positions by Release Height")
plt.grid(True)
plt.savefig("figures/displacementVSrelease-PISCO.png", dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert to DataFrame
df_settle = pd.DataFrame(settling_records, columns=['release_height', 'settling_time_hours'])

# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df_settle['release_height'], df_settle['settling_time_hours'], s=10, alpha=0.4)
plt.xlabel("Release Height (m)")
plt.ylabel("Settling Time (hours)")
plt.title("Settling Time vs. Release Height")
plt.grid(True)
plt.savefig("figures/settling_time_vs_release_height-PISCO.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
means = df_settle.groupby('release_height')['settling_time_hours'].mean()
plt.plot(means.index, means.values, color='black', lw=2)

# %%
distance = np.sqrt(x**2 + y**2)

plt.figure(figsize=(8, 6))
plt.scatter(release_h, distance, alpha=0.5, s=10, c='blue')  # Optional: use c=distance, cmap='viridis' for gradient

plt.xlabel("Release Height (m)")
plt.ylabel("Distance Traveled (m)")
plt.title("Dispersal Distance vs. Release Height")
plt.grid(True)
plt.savefig("figures/dispersaldistVSreleaseheight-PISCO.png", dpi=300, bbox_inches='tight')  # Save to current working dir
plt.show()

# %%
import seaborn as sns

sns.regplot(x=release_h, y=distance, scatter_kws={'s':10, 'alpha':0.5}, lowess=True)
plt.xlabel("Release Height (m)")
plt.ylabel("Distance Traveled (m)")
plt.title("Trend: Dispersal Distance vs. Release Height")
plt.grid(True)
plt.savefig("figures/all_releaseVSdistance-PISCO.png", dpi=300, bbox_inches='tight')  # Save as PNG
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


# Rebuild final positions and release height labels
all_final_positions = []
release_heights_list = []
settled_list = []

for r in release_heights:
    for pd_val in plant_depths:
        label = f"r{r}_pd{pd_val}"
        data = results.get(label)
        if data is None:
            continue

        #sanity check
        if not isinstance(data, tuple) or len(data) !=3:
            print(f"Skipping {label} - Unexpected format: {type(data)} with length {len(data) if hasattr(data, '__len__') else 'N/A'}")
            continue
            
        final_positions, settling_times, settled_flags = data

        print(f"{label}: final_positions.shape = {final_positions.shape}, settled_flags length = {len(settled_flags)}")
        
        #results[label] = (final_positions, settling_times, settled_flags)
        if final_positions.size == 0:
            print(f"Skipping {label} - no final positions")
            continue
            
        all_final_positions.append(final_positions)
        release_heights_list.extend([r] * final_positions.shape[0])
        settled_list.extend(settled_flags.tolist())

       # # Ensure it's a tuple of exactly 2 elements
       # if isinstance(data, tuple) and len(data) == 2:
        #    final_positions, settling_times = data

       #     if isinstance(final_positions, np.ndarray) and final_positions.size > 0:
       #         all_final_positions.append(final_positions)
       #         release_heights_list.extend([r] * final_positions.shape[0])
       # else:
       #     print(f"Skipping {label} — unexpected data format or empty.")

# Stack everything together
#if not all_final_positions:
#    raise ValueError("No valid final positions found. Check simulation output.")

all_final_positions = np.vstack(all_final_positions)
release_heights_array = np.array(release_heights_list)
settled_arr = np.array(settled_list)

# Build DataFrame
df_particles = pd.DataFrame({
    'x': all_final_positions[:, 0],
    'y': all_final_positions[:, 1],
    'release_height': release_heights_array,
    'settled': settled_arr
})

# Define bins (1 m increments)
start_heights = np.arange(0.0, 21.0, 1.0)
bin_ranges = [(start, start + 1) for start in start_heights]
bin_labels = [f"{low:.2f}–{high:.2f} m" for low, high in bin_ranges]

def assign_bin(height):
    for (low, high), label in zip(bin_ranges, bin_labels):
        if low <= height < high:
            return label
    return np.nan

df_particles['release_bin'] = df_particles['release_height'].apply(assign_bin)
df_particles = df_particles.dropna(subset=['release_bin'])

# Make release_bin ordered
df_particles['release_bin'] = pd.Categorical(
    df_particles['release_bin'],
    categories=bin_labels,
    ordered=True
)

color_map = {
    True: 'green',
    False: 'red'
}

# Plot layout
n_bins = len(bin_labels)
n_cols = 4
n_rows = int(np.ceil(n_bins / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 4 * n_rows), constrained_layout=True)
axes = axes.flatten()

# Plot by bin
for i, (bin_label, group) in enumerate(df_particles.groupby('release_bin', sort=False)):
    ax = axes[i]
    settled_patch = mpatches.Patch(color='green', label='Settled')
    not_settled_patch = mpatches.Patch(color='red', label='Not Settled')
    axes[0].legend(handles=[settled_patch, not_settled_patch], loc='best')
    colors = group['settled'].map(color_map)
    ax.scatter(group['x'], group['y'], s=5, alpha=0.6, c = colors)
    ax.set_title(f"Release Height: {bin_label}")
    ax.set_xlabel("Eastward Displacement (m)")
    ax.set_ylabel("Northward Displacement (m)")
    ax.grid(True)

# Hide unused subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.suptitle("Zygote Final Positions by Release Height Bins", fontsize=16)
plt.savefig("figures/faceted_displacement_ordered-PISCO.png.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# r0.5_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.55_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.6000000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.6500000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.7000000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.7500000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.8000000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.8500000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.9000000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r0.9500000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.0000000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.0500000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.1000000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.1500000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.2000000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.2500000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.3000000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.3500000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.4000000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.4500000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.5000000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.550000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.600000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.650000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.700000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.750000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.8000000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.8500000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.9000000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r1.9500000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.0000000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.0500000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.1000000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.1500000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.2000000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.2500000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.3000000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.3500000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.4000000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.450000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.5000000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.5500000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.600000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.650000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.700000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.7500000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.800000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.8500000000000023_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.900000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r2.950000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.000000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.0500000000000025_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.1000000000000023_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.150000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.2000000000000024_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.2500000000000027_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.3000000000000025_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.3500000000000023_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.4000000000000026_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.450000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.5000000000000027_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.5500000000000025_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.6000000000000028_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.650000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.700000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.7500000000000027_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.800000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.850000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.900000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r3.950000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.0000000000000036_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.050000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.100000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.150000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.200000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.2500000000000036_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.300000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.350000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.400000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.450000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.5000000000000036_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.550000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.600000000000003_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.650000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.700000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.7500000000000036_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.800000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.850000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.900000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r4.950000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.0000000000000036_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.050000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.100000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.150000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.200000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.250000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.300000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.350000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.400000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.450000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.500000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.550000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.600000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.650000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.700000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.750000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.800000000000004_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.850000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.900000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r5.950000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.000000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.050000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.100000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.150000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.200000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.250000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.300000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.350000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.400000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.4500000000000055_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.500000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.550000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.600000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.650000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.7000000000000055_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.750000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.800000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.850000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.900000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r6.9500000000000055_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.000000000000005_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.050000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.100000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.150000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.200000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.250000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.300000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.350000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.400000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.450000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.500000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.550000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.600000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.650000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.700000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.750000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.800000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.850000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.900000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r7.950000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.000000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.050000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.100000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.150000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.200000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.250000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.300000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.350000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.400000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.450000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.500000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.550000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.600000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.650000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.700000000000006_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.750000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.800000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.850000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.900000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r8.950000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.000000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.050000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.100000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.150000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.200000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.250000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.300000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.350000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.400000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.450000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.500000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.550000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.600000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.650000000000007_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.700000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.750000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.800000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.850000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.90000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r9.950000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.000000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.050000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.100000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.15000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.200000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.250000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.300000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.350000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.40000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.450000000000008_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.500000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.55000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.600000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.65000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.70000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.750000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.80000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.850000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.90000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r10.95000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.000000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.05000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.100000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.15000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.20000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.250000000000009_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.30000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.35000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.40000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.45000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.50000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.55000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.60000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.65000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.70000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.75000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.80000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.85000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.90000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r11.95000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.00000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.05000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.10000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.150000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.20000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.25000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.300000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.35000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.400000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.45000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.50000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.550000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.60000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.650000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.70000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.75000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.800000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.85000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.900000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r12.950000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.00000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.050000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.100000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.150000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.200000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.25000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.300000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.350000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.400000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.450000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.50000000000001_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.550000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.600000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.650000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.700000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.750000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.800000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.850000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.900000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r13.950000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.000000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.050000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.100000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.150000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.200000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.250000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.300000000000011_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.350000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.400000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.450000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.500000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.550000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.600000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.650000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.700000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.750000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.800000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.850000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.900000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r14.950000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.000000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.050000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.100000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.150000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.200000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.250000000000012_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.300000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.350000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.400000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.450000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.500000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.550000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.600000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.650000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.700000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.750000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.800000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.850000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.900000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r15.950000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.000000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.050000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.100000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.150000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.200000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.250000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.300000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.350000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.400000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.450000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.500000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.550000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.600000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.650000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.700000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.750000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.800000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.850000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.900000000000013_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r16.950000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.000000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.050000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.100000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.150000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.200000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.250000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.300000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.350000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.400000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.450000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.500000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.550000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.600000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.650000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.700000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.750000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.800000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.850000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.900000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r17.950000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.000000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.050000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.100000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.150000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.200000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.250000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.300000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.350000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.400000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.450000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.500000000000014_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.550000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.600000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.650000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.700000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.750000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.800000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.850000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.900000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r18.950000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.000000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.050000000000015_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.100000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.150000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.200000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.250000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.30000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.350000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.400000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.450000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.500000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.55000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.600000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.650000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.700000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.750000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.80000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.850000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.900000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r19.950000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.000000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.05000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.100000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.150000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.200000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.250000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.30000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.35000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.400000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.450000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.500000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.55000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.60000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.650000000000016_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.700000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.750000000000018_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.80000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.85000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.90000000000002_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# r20.950000000000017_pd21.0: final_positions.shape = (300, 3), settled_flags length = 300
# /var/folders/t6/9mj5h_qd17d697_8bs8tsr2c0000gn/T/ipykernel_29762/1433416508.py:98: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for i, (bin_label, group) in enumerate(df_particles.groupby('release_bin', sort=False)):

# %% [markdown]
# plant_depths = [21.0]
# sinking_speeds = [0.0009020192]  # must be iterable
#
# results = {}
#
# for r in release_heights:
#     for pd_val in plant_depths:
#         for ss in sinking_speeds:
#             label = f"r{r}_pd{pd_val}"
#             trajectories = run_simulation(release_height=r, plant_depth=pd_val, sinking_speeds=ss)
#             results[label] = trajectories
#
# # Combine all final positions and label by release height
# all_final_positions = []
# release_labels = []
#
# for r in release_heights:
#     for pd_val in plant_depths:
#         label = f"r{r}_pd{pd_val}"
#         data = results.get(label)
#         if data is not None and data.size > 0:
#             all_final_positions.append(data)
#             release_labels.extend([r] * data.shape[0])  # Tag with release height
#
# # Stack all final positions into a single array
# all_final_positions = np.vstack(all_final_positions)
# release_labels = np.array(release_labels)
#
# # Unpack x, y positions
# x = all_final_positions[:, 0]
# y = all_final_positions[:, 1]
#
# # Plot final particle positions colored by release height
# plt.figure(figsize=(8, 6))
# scatter = plt.scatter(x, y, c=release_labels, cmap='viridis', s=10)
# cbar = plt.colorbar(scatter, label="Release Height (m)")
# plt.xlabel("Eastward Displacement (m)")
# plt.ylabel("Northward Displacement (m)")
# plt.title("Final Particle Positions Colored by Release Height")
# plt.grid(True)
# plt.show()
#
# # Dispersal Kernel density
#
# from scipy.stats import gaussian_kde
#
# # Remove invalid points
# mask = np.isfinite(x) & np.isfinite(y)
# final_x = x[mask]
# final_y = y[mask]
#
# # KDE
# xy = np.vstack([final_x, final_y])
# kde = gaussian_kde(xy)
#
# # Grid for KDE evaluation
# xgrid, ygrid = np.meshgrid(
#     np.linspace(final_x.min() - 10, final_x.max() + 10, 100),
#     np.linspace(final_y.min() - 10, final_y.max() + 10, 100)
# )
# positions_kde = np.vstack([xgrid.ravel(), ygrid.ravel()])
# density = kde(positions_kde).reshape(xgrid.shape)
#
# plt.figure(figsize=(8, 6))
# plt.contourf(xgrid, ygrid, density, cmap='viridis')
# plt.colorbar(label="Kernel density")
# plt.scatter(final_x, final_y, c='red', s=10)
# plt.title("Dispersal Kernel Density")
# plt.xlabel("X position")
# plt.ylabel("Y position")
# plt.show()

# %% [markdown]
# #### **different types of plots - faceted**
